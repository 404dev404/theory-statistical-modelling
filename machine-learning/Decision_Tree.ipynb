# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## What is a Decision Tree?

# %% [markdown]
# A Decision Tree is a type of supervised learning algorithm that is used for classification problems. The name Decision Trees comes from it's tree based approach in classifying problems.
# ___________________

# %% [markdown]
# ## Types of Decision Trees

# %% [markdown]
# Decision trees can come in two forms:
#
# * **Categorical Variable**: Whereby we attempt to predict some binary attribute given a set of features.  Yes or No
# * **Continuous Variables**: Where we attempt to predict some continous variable based of a Decision Rule. (Salary <= 50K, Salary > 50K )
#
# __________

# %% [markdown]
# ### Terminologies related to Decision Trees

# %% [markdown]
# **Root Node: ** represents the entire population and sample and this gets further divided into two or more homogeneous sets.(Parent Node)
#
# **Splitting: ** it is a process of dividing a node into two or more sub-node. (Edges)
#
# **Decision Node: ** When a sub-node splits into further sub-nodes. Then it is called a decision node. (Child Node)
#
# **Leaf / Terminal Node: ** Nodes that do not split is called a Leaf or Terminal Node. (Base Case for Categorical Data)
#
# **Pruning: ** When we remove sub-nodes of a decision tree, this process is called pruning. Opposite of splitting
#
# **Branch / Sub-Tree: ** A sub section of entire tree is called branch or sub-tree.
#
# **Parent and Child Node: ** A node, which is divided into sub-nodes is called parent node of sub-nodes where as sub-nodes are the child of parent node.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## DECISION TREE SPLITTING

# %% [markdown]
# There are two primary methods Decision Tree decide which criterion to split on. These methods are often called the **Decision Tree Criterion**. The decision to use either criterion, has been noted to make little to no difference in the final accuracy. Nonetheless, as a general rule, the _Gini Index_ is often the prefered way to split Decision Tree.

# %% [markdown]
# ### Gini Index

# %% [markdown]
# ![Test](https://cdn-images-1.medium.com/max/1600/0*mvoE2G7vVaJ2ALEf.)

# %% [markdown]
# The Gini Index, operates under a few basic principle. It measures the varaince or _impurity_ across all classes of the data. Our objective is to make make it such that the entropy of a split is equal to 0. Such that, from our figure, we want to our split to be as far to the left side, or right side as much as possible.

# %% [markdown]
# This is as an Entropy of 0, indicates that we have perfect seperation between the two groups, whereas a probability of 0.5, indicates the worst split possible.

# %% [markdown]
# ## Advantages and Disadvantages of Decision Tree

# %% [markdown]
# ### Advantages

# %% [markdown]
# **Easy to Understand: ** Decision tree outputs are easy to understand for people with non-analytical backgrounds
#
# **Useful in Data Exploration: ** Decision Tree is one of the fastest way to identify most significant variables in relation between two or more variables. With decision trees, we can create new features that are more valuable in predicting the target variable.
#
# **Less data cleaning required: ** It requires less data cleaning compared to other ML methods. Not influenced by outliers or missing values to a fair degree.
#
# **Data Type Flexibility: ** Can handle both numerical and categorical data

# %% [markdown]
# ### Disadvantages

# %% [markdown]
# **Over fitting: ** Decision Trees tend to overfit data, hence the predicated score may be higher than actual predication. This problem can be solved by setting contraints on model parameters and pruning.
#
# ____________

# %% [markdown]
# ## Ensemble Method in Tree Based Modeling

# %% [markdown]
# The literary meaning of word ‘ensemble’ is group. Ensemble methods involve group of predictive models to achieve a better accuracy and model stability. Ensemble methods are known to impart supreme boost to tree based models.
#
# Like every other model, a tree based model also suffers from the plague of bias and variance. Bias means, ‘how much on an average are the predicted values different from the actual value.’ Variance means, ‘how different will the predictions of the model be at the same point if different samples are taken from the same population’.
#
# You build a small tree and you will get a model with low variance and high bias. How do you manage to balance the trade off between bias and variance ?
#
# Normally, as you increase the complexity of your model, you will see a reduction in prediction error due to lower bias in the model. As you continue to make your model more complex, you end up over-fitting your model and your model will start suffering from high variance.
#
# A champion model should maintain a balance between these two types of errors. This is known as the **management of bias-variance tradoff**. Ensemble learning is one way to execute this trade off analysis.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Some of the commonly used ensemble methods include: Bagging, Boosting and Stacking. In this tutorial, we’ll focus on Bagging and Boosting in detail.
#
# ____________

# %% [markdown]
# ### What is Bagging? How does it work?

# %% [markdown]
# Bagging is a technique used to reduce the variance of our predictions by combining the result of multiple classifiers modeled on different sub-samples of the same data set. See figure below:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The steps followed in bagging are:
#
# **1. Create Multiple DataSets: **
#
#    - Sampling is done with replacement on the original data and new datasets are formed.
#    - The new data sets can have a fraction of the columns as well as rows, which are generally hyper-parameters in a bagging model
#    - Taking row and column fractions less than 1 helps in making robust models, less prone to overfitting
#
# **2. Build Multiple Classifiers:**
#
# - Classifiers are built on each data set.
# - Generally the same classifier is modeled on each data set and predictions are made.
#
# **3. Combine Classifiers:**
#
# - The predictions of all the classifiers are combined using a mean, median or mode value depending on the problem at hand.
# - The combined values are generally more robust than a single model.
#
#
# There are various implementations of bagging models. Random forest is one of them and we’ll discuss it next.
#
# __________
# ________

# %% [markdown]
# ## 4. What is Random Forest? How does it work?

# %% [markdown]
# ### Advantages of Random Forest

# %% [markdown]
# **Classification & Regression: **This algorithm can solve both types of problems. I.e. classification and regression and does a decent estimation at both fronts.
#
# **Higher Dimensional Data Sets: **It is capable of handling large data sets with higher dimensionality. It can handle thousands of input variables and identify the most significant variables, so it is considered as one of the dimensionality reduction methods. Further the model ouputs importance of variables, which can be a very handy feature.

# %% [markdown]
# **Missing Values: ** Effective in estimating missing data and maintaining accuracy when a large proportion of the data is missing.
#
# **Balancing Outliers / Errors: ** It has methods for balancing errors in data sets where classes are imbalanced
#
# **Unsupervised Clustering: ** Has the capacity to extend to unlabeled data, leading to unsupervised clusters for data views and outlier detection.
#
# **Out Of Bag: ** Random Forest involves sampling of the input data with replacement called as bootstrap sampling. Here 30% of the data was not used for training and can be used for testing. This method is called out of bag sampling. Error estimated on these out of bag samples is known as out of bag errors. Study of error estimates by Out of bag, gives evidence to show that the out-of-bag estimate is as accurate as using a test set of the same size as the training set. Hence the use of Random Forest out of bag error estimate removes the need to set aside testing data
#
# _________
# _________

# %% [markdown]
# ## 5. Gradient Boosting? How does it work?

# %% [markdown]
# **Definition: ** The term 'Boosting' refers to a family of algorithms which converts weak learner to strong learners.
#
# The term ‘Boosting’ refers to a family of algorithms which converts weak learner to strong learners.
#
# Let’s understand this definition in detail by solving a problem of spam email identification:
#
# How would you classify an email as SPAM or not? Like everyone else, our initial approach would be to identify ‘spam’ and ‘not spam’ emails using following criteria. If:
#
# - Email has only one image file (promotional image), It’s a SPAM
# - Email has only link(s), It’s a SPAM
# - Email body consist of sentence like “You won a prize money of  xxxxxx”, It’s a SPAM
# - Email from our official domain “google.com” , Not a SPAM
# - Email from known source, Not a SPAM
#
# Above, we’ve defined multiple rules to classify an email into ‘spam’ or ‘not spam’. But, do you think these rules individually are strong enough to successfully classify an email? No.
#
# Individually, these rules are not powerful enough to classify an email into ‘spam’ or ‘not spam’. Therefore, these rules are called as weak learner.
#
# **To convert weak learner to strong learner, we’ll combine the prediction of each weak learner using methods like:**
#
# Using average/ weighted average
#
# Considering prediction has higher vote:
# - For example:  Above, we have defined 5 weak learners. Out of these 5, 3 are voted as ‘SPAM’ and 2 are voted as ‘Not a SPAM’. In this case, by default, we’ll consider an email as SPAM because we have higher(3) vote for ‘SPAM’.

# %% [markdown]
# ### Gradient Boosting Method (GBM) vs Extreme Gradient Boosting (XgBoost)

# %% [markdown]
# **Both xgboost and gbm: ** follows the principle of gradient boosting.  There are however, the difference in modeling details. Specifically,  xgboost used a more regularized model formalization to control over-fitting, which gives it better performance.
#
# **XgBoost is better overall. Just use it as a default, since it can be intergrated with Hadoop, supports parrallel processing, and is more regularized to control for overfitting.**

# %% [markdown]
# ### Gradient Boosting Method & Parameters

# %% [markdown]
# **Important GBM parameters to improve the model performance in Python: **

# %% [markdown]
# 1. **learning_rate**
#  - Helps determine the impact of each tree on the final outcome. GBM starts with an initial estimate which is updated using the output of each tree. the learning parameter controls the magnitude of this change in the estimate. Alvin Notes: Basically an Elo algorithm in which you can adjust the maginitude of change for ranks
#
#  - Lowers valuyes are generally preferred as they make the model robust to the specific characteristics of the tree and thuse allowing it to generalize the data well.
#
#  - With that, Lower values would require a higher number of trees to model all the relations, and make the dataset more accurate.
#
#
# 1. **n_estimators**
#  - the number of sequrential trees to be modeled
#  - Though GBM is faily robust at higher number of trees but it can still overfit at a point. Hence this should be tuned.
#
#
# 3. **subsample**
#  - The fraction of observations to be selected for each tree. Selection is done by random sampling.
#  - Values slightly less than 1 make the model robust by reducing the variance.
#  - Typical values ~0.8 generally work fine but can be fine-tuned further.

# %% [markdown]
# ## Code for Decision Tree & Random Forest Method

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Import decision Treee
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.cross_validation import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
# Out:
# /Users/alvinchung/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Import csv into DataFrame
df = pd.read_csv('iris.csv')

# %%
# Check if there is any null's in the Dataset
print(df.isnull().any())
print(df.dtypes)
# Out:
# Sepal.Length    False
# Sepal.Width     False
# Petal.Length    False
# Petal.Width     False
# Species         False
# dtype: bool
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
print("Length of Dataset: ", len(df))
print("Dataset Shape: ",df.shape)
# Out:
# Length of Dataset:  150
# Dataset Shape:  (150, 5)

# %%
df.Species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.FacetGrid(df, hue="Species",size = 10) \
   .map(plt.scatter, "Sepal.Length", "Sepal.Width") \
   .add_legend()

# %%
X = df.values[:,0:3]
Y = df.values[:,4:5]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,random_state = 3)

# %%
model = tree.DecisionTreeClassifier(criterion = 'gini')
model.fit(X_train,Y_train);
model.score(X_train,Y_train)
# Out:
# 1.0

# %%
Y_predict = model.predict(X_test)
Y_predict
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'virginica', 'virginica', 'setosa', 'virginica',
#        'virginica', 'virginica', 'virginica', 'setosa', 'virginica',
#        'versicolor', 'versicolor', 'virginica', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'virginica', 'versicolor', 'virginica',
#        'versicolor', 'setosa', 'setosa', 'virginica'], dtype=object)

# %%
print("Accuracy is",round(accuracy_score(Y_test,Y_predict)*100),"%")
# Out:
# Accuracy is 89.0 %

# %%
model = RandomForestClassifier(n_estimators = 1000)
model.fit(X_train,Y_train)
Y_predict = model.predict(X_test)
# Out:
# /Users/alvinchung/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
print("Model Accuracy after Random Forest: ",round(accuracy_score(Y_test,Y_predict)*100), "%")
# Out:
# Model Accuracy after Random Forest:  93.0 %
